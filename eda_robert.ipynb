# %% [markdown]
# # 📊 EDA Project - Robert Davis
#
# ## 1. Project Goal
# Explore a dataset using basic Exploratory Data Analysis (EDA) techniques.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Enable inline plotting for charts
# %matplotlib inline

# %%
# Import required Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visual style
sns.set(style="whitegrid")

# %%
df = sns.load_dataset("tips")

# Show the first five rows
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Summary of column names, data types, and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# Summary statistics for numeric columns
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: set a style
sns.set(style="whitegrid")

# Enable inline plotting for Jupyter
# %matplotlib inline

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the built-in tips dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tips["total_bill"], kde=True, bins=20)
plt.title("Distribution of Total Bill")
plt.xlabel("Total Bill ($)")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(tips["tip"], kde=True, bins=20)
plt.title("Distribution of Tip Amount")
plt.xlabel("Tip ($)")
plt.ylabel("Frequency")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.title("Tip vs. Total Bill")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
plt.show()

# %%
sns.boxplot(data=tips, x="sex", y="tip")
plt.title("Tip Distribution by Sex")
plt.xlabel("Sex")
plt.ylabel("Tip ($)")
plt.show()

# %%
sns.violinplot(data=tips, x="day", y="tip")
plt.title("Tip Distribution by Day")
plt.xlabel("Day of Week")
plt.ylabel("Tip ($)")
plt.show()

# %%
sns.heatmap(tips.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
avg_tip_by_day = tips.groupby("day")["tip"].mean()
print("Average Tip by Day:")
print(avg_tip_by_day)
# Out:
# Average Tip by Day:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64
# C:\Users\Rober\AppData\Local\Temp\ipykernel_153820\2580300231.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_tip_by_day = tips.groupby("day")["tip"].mean()

# %%
avg_tip_by_day.plot(kind="bar", title="Average Tip by Day", ylabel="Average Tip ($)", xlabel="Day of Week")
plt.show()

# %%
total_bill_by_time = tips.groupby("time")["total_bill"].sum()
print("Total Bill by Time:")
print(total_bill_by_time)

total_bill_by_time.plot(kind="bar", title="Total Bill by Time", ylabel="Total Bill ($)", xlabel="Meal Time")
plt.show()
# Out:
# Total Bill by Time:
# time
# Lunch     1167.47
# Dinner    3660.30
# Name: total_bill, dtype: float64
# C:\Users\Rober\AppData\Local\Temp\ipykernel_153820\3903215932.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_bill_by_time = tips.groupby("time")["total_bill"].sum()

# %%
tips["tip_percent"] = 100 * tips["tip"] / tips["total_bill"]

# %%
avg_tip_percent_by_smoker = tips.groupby("smoker")["tip_percent"].mean()
print("Average Tip % by Smoker:")
print(avg_tip_percent_by_smoker)

avg_tip_percent_by_smoker.plot(kind="bar", title="Average Tip % by Smoker", ylabel="Tip %", xlabel="Smoker")
plt.show()
# Out:
# Average Tip % by Smoker:
# smoker
# Yes    16.319604
# No     15.932846
# Name: tip_percent, dtype: float64
# C:\Users\Rober\AppData\Local\Temp\ipykernel_153820\81128224.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_tip_percent_by_smoker = tips.groupby("smoker")["tip_percent"].mean()

# %%
# Save to CSV
avg_tip_percent_by_smoker.to_csv("results/avg_tip_percent_by_smoker.csv")
print("✅ Saved avg_tip_percent_by_smoker.csv")
# Out:
# ✅ Saved avg_tip_percent_by_smoker.csv

# %%
import os
os.makedirs("results", exist_ok=True)

# %%
# Save to CSV
avg_tip_percent_by_smoker.to_csv("results/avg_tip_percent_by_smoker.csv")
print("✅ Saved avg_tip_percent_by_smoker.csv")
# Out:
# ✅ Saved avg_tip_percent_by_smoker.csv

# %%
# Save to CSV
avg_tip_percent_by_smoker.to_csv("results/avg_tip_percent_by_smoker.csv")
print("✅ Saved avg_tip_percent_by_smoker.csv")
# Out:
# ✅ Saved avg_tip_percent_by_smoker.csv

# %%
# Create the chart again and save it
avg_tip_by_day.plot(kind="bar", title="Average Tip by Day")
plt.ylabel("Average Tip ($)")
plt.xlabel("Day of Week")
plt.tight_layout()
plt.savefig("results/avg_tip_by_day_chart.png")
plt.close()
print("✅ Saved avg_tip_by_day_chart.png")
# Out:
# ✅ Saved avg_tip_by_day_chart.png

# %%
avg_tip_by_day.to_excel("results/avg_tip_by_day.xlsx")
print("✅ Saved avg_tip_by_day.xlsx")
# Out:
# ✅ Saved avg_tip_by_day.xlsx

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a Seaborn style
sns.set(style="whitegrid")

# Bar chart: Average tip by day
plt.figure(figsize=(8, 5))
sns.barplot(x="day", y="tip", data=df)
plt.title("Average Tip by Day")
plt.ylabel("Tip ($)")
plt.xlabel("Day of Week")
plt.tight_layout()
plt.savefig("results/avg_tip_by_day_bar.png")
plt.show()

# %%
# Ensure tip_percent is calculated
df["tip_percent"] = df["tip"] / df["total_bill"] * 100

# Box plot: Tip percent by smoker
plt.figure(figsize=(8, 5))
sns.boxplot(x="smoker", y="tip_percent", data=df)
plt.title("Tip Percent by Smoker Status")
plt.ylabel("Tip Percentage")
plt.xlabel("Smoker (Yes or No)")
plt.tight_layout()
plt.savefig("results/tip_percent_by_smoker_box.png")
plt.show()
